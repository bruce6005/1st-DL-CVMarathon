# %% [markdown]
# ## 『作業內容』
# ####   依照指示，透過調整Padding、Strides參數控制輸出Feature map大小

# %% [markdown]
# ## 『目標』
# ####   了解輸出feature map尺寸變化原理

# %%
from keras.models import Sequential
from keras.layers import Convolution2D
from keras.layers import Input, Dense
from keras.models import Model


##kernel size=(6,6)
##kernel數量：32

## Same padding、strides=(1,1)
classifier=Sequential()
inputs = Input(shape=(13,13,1))
x=Convolution2D(32,(6,6),padding='same',inputs=inputs)
x=classifier.add(Convolution2D(32,(6,6),padding='same',input_shape=input_shape))
model = Model(inputs=inputs, outputs=x)
print('sdfasdfasfd')
model.summary()
## Same padding、strides=(2,2)
classifier=Sequential()
inputs = Input(shape=(13,13,1))
x=Convolution2D()(inputs)
model = Model(inputs=inputs, outputs=x)
model.summary()
## Valid padding、strides=(1,1)
classifier=Sequential()
inputs = Input(shape=(13,13,1))
x=Convolution2D()(inputs)
model = Model(inputs=inputs, outputs=x)
model.summary()
## Valid padding、strides=(2,2)
classifier=Sequential()
inputs = Input(shape=(13,13,1))
x=Convolution2D()(inputs)
model = Model(inputs=inputs, outputs=x)
model.summary()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-08bdc497fd92> in <module>
#      11 classifier=Sequential()
#      12 inputs = Input(shape=(13,13,1))
# ---> 13 x=Convolution2D(32,(6,6),padding='same',inputs=inputs)
#      14 model = Model(inputs=inputs, outputs=x)
#      15 print('sdfasdfasfd')
#
# ~\Anaconda3\lib\site-packages\keras\legacy\interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# ~\Anaconda3\lib\site-packages\keras\layers\convolutional.py in __init__(self, filters, kernel_size, strides, padding, data_format, dilation_rate, activation, use_bias, kernel_initializer, bias_initializer, kernel_regularizer, bias_regularizer, activity_regularizer, kernel_constraint, bias_constraint, **kwargs)
#     488             kernel_constraint=kernel_constraint,
#     489             bias_constraint=bias_constraint,
# --> 490             **kwargs)
#     491
#     492     def get_config(self):
#
# ~\Anaconda3\lib\site-packages\keras\layers\convolutional.py in __init__(self, rank, filters, kernel_size, strides, padding, data_format, dilation_rate, activation, use_bias, kernel_initializer, bias_initializer, kernel_regularizer, bias_regularizer, activity_regularizer, kernel_constraint, bias_constraint, **kwargs)
#     103                  bias_constraint=None,
#     104                  **kwargs):
# --> 105         super(_Conv, self).__init__(**kwargs)
#     106         self.rank = rank
#     107         self.filters = filters
#
# ~\Anaconda3\lib\site-packages\keras\engine\base_layer.py in __init__(self, **kwargs)
#     126         for kwarg in kwargs:
#     127             if kwarg not in allowed_kwargs:
# --> 128                 raise TypeError('Keyword argument not understood:', kwarg)
#     129         name = kwargs.get('name')
#     130         if not name:
#
# TypeError: ('Keyword argument not understood:', 'inputs')

# %%
conda install keras
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.
