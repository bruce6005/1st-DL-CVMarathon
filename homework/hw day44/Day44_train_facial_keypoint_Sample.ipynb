# %% [markdown]
# ### 範例
# 接下來的程式碼會示範如何定義一個簡單的 CNN model

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 使用 colab 環境的同學請執行以下程式碼
# %tensorflow_version 1.x # 確保 colob 中使用的 tensorflow 是 1.x 版本而不是 tensorflow 2
# import tensorflow as tf
# print(tf.__version__)

# import os
# from google.colab import drive 
# drive.mount('/content/gdrive') # 將 google drive 掛載在 colob，
# %cd 'gdrive/My Drive'
# os.system("mkdir cupoy_cv_part4") # 可以自己改路徑
# %cd cupoy_cv_part4 # 可以自己改路徑

# %%
# 讀取資料集以及做前處理的函數
def load_data(dirname):
    # 讀取 csv 文件
    data = pd.read_csv(dirname)
    # 過濾有缺失值的 row
    data = data.dropna()

    # 將圖片像素值讀取為 numpy array 的形態
    data['Image'] = data['Image'].apply(lambda img: np.fromstring(img, sep=' ')).values 

    # 單獨把圖像 array 抽取出來
    imgs = np.vstack(data['Image'].values)/255
    # reshape 為 96 x 96
    imgs = imgs.reshape(data.shape[0], 96, 96)
    # 轉換為 float
    imgs = imgs.astype(np.float32)
    
    # 提取坐標的部分
    points = data[data.columns[:-1]].values

    # 轉換為 float
    points = points.astype(np.float32)

    # normalize 坐標值到 [-0.5, 0.5]
    points = points/96 - 0.5
    
    return imgs, points

# %%
# 讀取資料
imgs_train, points_train = load_data(dirname = 'training.csv')
print("圖像資料:", imgs_train.shape, "\n關鍵點資料:", points_train.shape)
# Out:
# 圖像資料: (2140, 96, 96)
# 關鍵點資料: (2140, 30)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
# Out:
# Using TensorFlow backend.

# %%
# 回傳定義好的 model 的函數
def get_model():
    # 定義人臉關鍵點檢測網路
    model = Sequential()

    # 定義神經網路的輸入
    model.add(Conv2D(filters=16, kernel_size=3, activation='relu', input_shape=(96, 96, 1)))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=32, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=64, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=128, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))

    # 最後輸出 30 維的向量，也就是 15 個關鍵點的值
    model.add(Dense(30))
    return model

# %%
model = get_model()
# 配置 loss funtion 和 optimizer
model.compile(loss='mean_squared_error', optimizer='adam')
# Out:
# WARNING:tensorflow:From C:\Users\User\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\User\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From C:\Users\User\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From C:\Users\User\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From C:\Users\User\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From C:\Users\User\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From C:\Users\User\Anaconda3\lib\site-packages\keras\optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
# 印出網路結構
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 94, 94, 16)        160
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 47, 47, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 45, 45, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 22, 22, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 20, 20, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               1049088
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 30)                15390
# =================================================================
# Total params: 1,424,286
# Trainable params: 1,424,286
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, History
# model checkpoint 
checkpoint = ModelCheckpoint('best_weights.h5', verbose=1, save_best_only=True)
hist = History()

# %%
# training the model
hist_model = model.fit(imgs_train.reshape(-1, 96, 96, 1), 
                       points_train, 
                       validation_split=0.2, batch_size=64, callbacks=[checkpoint, hist],
                       shuffle=True, epochs=150, verbose=1)
# save the model weights
model.save_weights('weights.h5')
# save the model
model.save('model.h5')
# Out:
# WARNING:tensorflow:From C:\Users\User\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From C:\Users\User\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From C:\Users\User\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:2741: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# Train on 1712 samples, validate on 428 samples
# Epoch 1/150
# WARNING:tensorflow:From C:\Users\User\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From C:\Users\User\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From C:\Users\User\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From C:\Users\User\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From C:\Users\User\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:206: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# 1712/1712 [==============================] - 8s 5ms/step - loss: 0.0061 - val_loss: 0.0021
#
# Epoch 00001: val_loss improved from inf to 0.00208, saving model to best_weights.h5
# Epoch 2/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 0.0016 - val_loss: 0.0019
#
# Epoch 00002: val_loss improved from 0.00208 to 0.00189, saving model to best_weights.h5
# Epoch 3/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 0.0013 - val_loss: 0.0020
#
# Epoch 00003: val_loss did not improve from 0.00189
# Epoch 4/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 0.0012 - val_loss: 0.0019
#
# Epoch 00004: val_loss did not improve from 0.00189
# Epoch 5/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 0.0011 - val_loss: 0.0018
#
# Epoch 00005: val_loss improved from 0.00189 to 0.00182, saving model to best_weights.h5
# Epoch 6/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 9.6859e-04 - val_loss: 0.0018
#
# Epoch 00006: val_loss improved from 0.00182 to 0.00179, saving model to best_weights.h5
# Epoch 7/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 8.3714e-04 - val_loss: 0.0016
#
# Epoch 00007: val_loss improved from 0.00179 to 0.00160, saving model to best_weights.h5
# Epoch 8/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 7.2044e-04 - val_loss: 0.0015
#
# Epoch 00008: val_loss improved from 0.00160 to 0.00150, saving model to best_weights.h5
# Epoch 9/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 6.2934e-04 - val_loss: 0.0013
#
# Epoch 00009: val_loss improved from 0.00150 to 0.00126, saving model to best_weights.h5
# Epoch 10/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 5.8061e-04 - val_loss: 0.0013
#
# Epoch 00010: val_loss did not improve from 0.00126
# Epoch 11/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 5.1094e-04 - val_loss: 0.0012
#
# Epoch 00011: val_loss improved from 0.00126 to 0.00120, saving model to best_weights.h5
# Epoch 12/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 5.1323e-04 - val_loss: 0.0011
#
# Epoch 00012: val_loss improved from 0.00120 to 0.00113, saving model to best_weights.h5
# Epoch 13/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 4.6585e-04 - val_loss: 0.0011
#
# Epoch 00013: val_loss improved from 0.00113 to 0.00107, saving model to best_weights.h5
# Epoch 14/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 4.2282e-04 - val_loss: 0.0010
#
# Epoch 00014: val_loss improved from 0.00107 to 0.00103, saving model to best_weights.h5
# Epoch 15/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 4.0317e-04 - val_loss: 9.9894e-04
#
# Epoch 00015: val_loss improved from 0.00103 to 0.00100, saving model to best_weights.h5
# Epoch 16/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 3.6995e-04 - val_loss: 9.3589e-04
#
# Epoch 00016: val_loss improved from 0.00100 to 0.00094, saving model to best_weights.h5
# Epoch 17/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 3.6408e-04 - val_loss: 9.1499e-04
#
# Epoch 00017: val_loss improved from 0.00094 to 0.00091, saving model to best_weights.h5
# Epoch 18/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 3.3620e-04 - val_loss: 9.0659e-04
#
# Epoch 00018: val_loss improved from 0.00091 to 0.00091, saving model to best_weights.h5
# Epoch 19/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 3.3027e-04 - val_loss: 9.0141e-04
#
# Epoch 00019: val_loss improved from 0.00091 to 0.00090, saving model to best_weights.h5
# Epoch 20/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 3.1744e-04 - val_loss: 8.8178e-04
#
# Epoch 00020: val_loss improved from 0.00090 to 0.00088, saving model to best_weights.h5
# Epoch 21/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 3.0615e-04 - val_loss: 8.8257e-04
#
# Epoch 00021: val_loss did not improve from 0.00088
# Epoch 22/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.9198e-04 - val_loss: 8.2981e-04
#
# Epoch 00022: val_loss improved from 0.00088 to 0.00083, saving model to best_weights.h5
# Epoch 23/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.8103e-04 - val_loss: 8.4545e-04
#
# Epoch 00023: val_loss did not improve from 0.00083
# Epoch 24/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.7600e-04 - val_loss: 8.3742e-04
#
# Epoch 00024: val_loss did not improve from 0.00083
# Epoch 25/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.6959e-04 - val_loss: 8.1705e-04
#
# Epoch 00025: val_loss improved from 0.00083 to 0.00082, saving model to best_weights.h5
# Epoch 26/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.6668e-04 - val_loss: 8.2989e-04
#
# Epoch 00026: val_loss did not improve from 0.00082
# Epoch 27/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.5194e-04 - val_loss: 8.2474e-04
#
# Epoch 00027: val_loss did not improve from 0.00082
# Epoch 28/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.5419e-04 - val_loss: 8.1811e-04
#
# Epoch 00028: val_loss did not improve from 0.00082
# Epoch 29/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.4108e-04 - val_loss: 8.7043e-04
#
# Epoch 00029: val_loss did not improve from 0.00082
# Epoch 30/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 2.4283e-04 - val_loss: 8.0650e-04
#
# Epoch 00030: val_loss improved from 0.00082 to 0.00081, saving model to best_weights.h5
# Epoch 31/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.2799e-04 - val_loss: 8.0130e-04
#
# Epoch 00031: val_loss improved from 0.00081 to 0.00080, saving model to best_weights.h5
# Epoch 32/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.3162e-04 - val_loss: 8.5433e-04
#
# Epoch 00032: val_loss did not improve from 0.00080
# Epoch 33/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.2708e-04 - val_loss: 8.0773e-04
#
# Epoch 00033: val_loss did not improve from 0.00080
# Epoch 34/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.2483e-04 - val_loss: 8.3110e-04
#
# Epoch 00034: val_loss did not improve from 0.00080
# Epoch 35/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.1389e-04 - val_loss: 7.8509e-04
#
# Epoch 00035: val_loss improved from 0.00080 to 0.00079, saving model to best_weights.h5
# Epoch 36/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.1300e-04 - val_loss: 8.0273e-04
#
# Epoch 00036: val_loss did not improve from 0.00079
# Epoch 37/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.0449e-04 - val_loss: 8.2900e-04
#
# Epoch 00037: val_loss did not improve from 0.00079
# Epoch 38/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.0314e-04 - val_loss: 7.9014e-04
#
# Epoch 00038: val_loss did not improve from 0.00079
# Epoch 39/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.0116e-04 - val_loss: 7.9281e-04
#
# Epoch 00039: val_loss did not improve from 0.00079
# Epoch 40/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.9924e-04 - val_loss: 7.7434e-04
#
# Epoch 00040: val_loss improved from 0.00079 to 0.00077, saving model to best_weights.h5
# Epoch 41/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.9858e-04 - val_loss: 7.9173e-04
#
# Epoch 00041: val_loss did not improve from 0.00077
# Epoch 42/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.9458e-04 - val_loss: 7.9018e-04
#
# Epoch 00042: val_loss did not improve from 0.00077
# Epoch 43/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.9950e-04 - val_loss: 8.1039e-04
#
# Epoch 00043: val_loss did not improve from 0.00077
# Epoch 44/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.8994e-04 - val_loss: 7.7124e-04
#
# Epoch 00044: val_loss improved from 0.00077 to 0.00077, saving model to best_weights.h5
# Epoch 45/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.8767e-04 - val_loss: 7.8722e-04
#
# Epoch 00045: val_loss did not improve from 0.00077
# Epoch 46/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.8053e-04 - val_loss: 7.6440e-04
#
# Epoch 00046: val_loss improved from 0.00077 to 0.00076, saving model to best_weights.h5
# Epoch 47/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.8127e-04 - val_loss: 7.9138e-04
#
# Epoch 00047: val_loss did not improve from 0.00076
# Epoch 48/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.
-04
#
# Epoch 00118: val_loss did not improve from 0.00072
# Epoch 119/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 9.9274e-05 - val_loss: 7.8655e-04
#
# Epoch 00119: val_loss did not improve from 0.00072
# Epoch 120/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 9.5173e-05 - val_loss: 7.4335e-04
#
# Epoch 00120: val_loss did not improve from 0.00072
# Epoch 121/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 9.6651e-05 - val_loss: 7.4949e-04
#
# Epoch 00121: val_loss did not improve from 0.00072
# Epoch 122/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 9.6710e-05 - val_loss: 7.6090e-04
#
# Epoch 00122: val_loss did not improve from 0.00072
# Epoch 123/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 9.6937e-05 - val_loss: 7.9187e-04
#
# Epoch 00123: val_loss did not improve from 0.00072
# Epoch 124/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 9.7293e-05 - val_loss: 7.9011e-04
#
# Epoch 00124: val_loss did not improve from 0.00072
# Epoch 125/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 9.4162e-05 - val_loss: 7.6732e-04
#
# Epoch 00125: val_loss did not improve from 0.00072
# Epoch 126/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 9.1322e-05 - val_loss: 7.4515e-04
#
# Epoch 00126: val_loss did not improve from 0.00072
# Epoch 127/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 9.7317e-05 - val_loss: 7.1062e-04
#
# Epoch 00127: val_loss improved from 0.00072 to 0.00071, saving model to best_weights.h5
# Epoch 128/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 9.2941e-05 - val_loss: 7.9679e-04
#
# Epoch 00128: val_loss did not improve from 0.00071
# Epoch 129/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 9.3037e-05 - val_loss: 7.6650e-04
#
# Epoch 00129: val_loss did not improve from 0.00071
# Epoch 130/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 9.6163e-05 - val_loss: 7.6025e-04
#
# Epoch 00130: val_loss did not improve from 0.00071
# Epoch 131/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 9.1788e-05 - val_loss: 7.6060e-04
#
# Epoch 00131: val_loss did not improve from 0.00071
# Epoch 132/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 8.9986e-05 - val_loss: 7.5249e-04
#
# Epoch 00132: val_loss did not improve from 0.00071
# Epoch 133/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 8.9171e-05 - val_loss: 7.3917e-04
#
# Epoch 00133: val_loss did not improve from 0.00071
# Epoch 134/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 9.1405e-05 - val_loss: 7.4081e-04
#
# Epoch 00134: val_loss did not improve from 0.00071
# Epoch 135/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 9.2594e-05 - val_loss: 7.6193e-04
#
# Epoch 00135: val_loss did not improve from 0.00071
# Epoch 136/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 8.9396e-05 - val_loss: 7.3989e-04
#
# Epoch 00136: val_loss did not improve from 0.00071
# Epoch 137/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 8.7146e-05 - val_loss: 7.4521e-04
#
# Epoch 00137: val_loss did not improve from 0.00071
# Epoch 138/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 9.0814e-05 - val_loss: 7.7200e-04
#
# Epoch 00138: val_loss did not improve from 0.00071
# Epoch 139/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 9.0799e-05 - val_loss: 7.7280e-04
#
# Epoch 00139: val_loss did not improve from 0.00071
# Epoch 140/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 8.7914e-05 - val_loss: 7.6708e-04
#
# Epoch 00140: val_loss did not improve from 0.00071
# Epoch 141/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 9.0774e-05 - val_loss: 7.4828e-04
#
# Epoch 00141: val_loss did not improve from 0.00071
# Epoch 142/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 8.7691e-05 - val_loss: 7.7569e-04
#
# Epoch 00142: val_loss did not improve from 0.00071
# Epoch 143/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 8.6094e-05 - val_loss: 7.4454e-04
#
# Epoch 00143: val_loss did not improve from 0.00071
# Epoch 144/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 8.5443e-05 - val_loss: 7.7046e-04
#
# Epoch 00144: val_loss did not improve from 0.00071
# Epoch 145/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 8.5262e-05 - val_loss: 7.5279e-04
#
# Epoch 00145: val_loss did not improve from 0.00071
# Epoch 146/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 8.4102e-05 - val_loss: 7.5830e-04
#
# Epoch 00146: val_loss did not improve from 0.00071
# Epoch 147/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 8.6270e-05 - val_loss: 7.6491e-04
#
# Epoch 00147: val_loss did not improve from 0.00071
# Epoch 148/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 8.4211e-05 - val_loss: 7.4154e-04
#
# Epoch 00148: val_loss did not improve from 0.00071
# Epoch 149/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 8.4659e-05 - val_loss: 7.5664e-04
#
# Epoch 00149: val_loss did not improve from 0.00071
# Epoch 150/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 8.5241e-05 - val_loss: 7.5914e-04
#
# Epoch 00150: val_loss did not improve from 0.00071

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')

# %% [markdown]
# ### 觀察 model 在 testing 上的結果

# %%
# 讀取測試資料集
imgs_test, _ = load_data(dirname = 'test.csv')

# %%
# 在灰階圖像上畫關鍵點的函數
def plot_keypoints(img, points):
    plt.imshow(img, cmap='gray')
    for i in range(0,30,2):
        plt.scatter((points[i] + 0.5)*96, (points[i+1]+0.5)*96, color='red')

# %%
fig = plt.figure(figsize=(15,15))
# 在測試集圖片上用剛剛訓練好的模型做關鍵點的預測
points_test = model.predict(imgs_test.reshape(imgs_test.shape[0], 96, 96, 1))

for i in range(16):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    plot_keypoints(imgs_test[i], np.squeeze(points_test[i]))

# %% [markdown]
# 目前為止，大致可以觀察到，直接使用簡單的模型以及訓練方式在這組數據上應該可以在訓練集和測試集上都得到一個還不錯的結果，說明這組資料其實不會很難。

# %% [markdown]
# ### 作業
# 請嘗試使用 flip (左右翻轉) 來做 augmentation 以降低人臉關鍵點檢測的 loss
#
# Note: 圖像 flip 之後，groundtruth 的關鍵點也要跟著 flip 哦

# %%
model_with_augment = get_model()
model_with_augment.compile(loss='mean_squared_error', optimizer='adam')

# %%
# Your code
