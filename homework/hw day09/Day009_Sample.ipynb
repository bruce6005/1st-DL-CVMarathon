# %% [markdown]
# # 範例
#
# 取得 SIFT 特徵
#
# - 轉成灰階圖片
# - 需要額外安裝 OpenCV 相關套件

# %%
import numpy as np
import cv2

img = cv2.imread('lena.png')

# %%
# 轉灰階圖片
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# 建立 SIFT 物件
SIFT_detector = cv2.xfeatures2d.SIFT_create()

# 取得 SIFT 關鍵點位置
keypoints = SIFT_detector.detect(img_gray, None)

#　畫圖 + 顯示圖片
img_show = cv2.drawKeypoints(img_gray, keypoints, img)
while True:
    cv2.imshow('SIFT', img_show)
    k = cv2.waitKey(0)
    if k == 27:
        cv2.destroyAllWindows()
        break

# %%
pip install opencv-contrib-python
# Out:
# Collecting opencv-contrib-python
#   Downloading https://files.pythonhosted.org/packages/2e/ff/9a133832a68540ddd9a2b706ff57f370b74fa15b74da46f70a615c19afe7/opencv_contrib_python-4.1.2.30-cp37-cp37m-win_amd64.whl (39.4MB)
# Requirement already satisfied: numpy>=1.14.5 in c:\users\user\anaconda3\lib\site-packages (from opencv-contrib-python) (1.16.5)
# Installing collected packages: opencv-contrib-python
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not install packages due to an EnvironmentError: [WinError 5] 存取被拒。: 'C:\\Users\\User\\Anaconda3\\Lib\\site-packages\\cv2\\cv2.cp37-win_amd64.pyd'
# Consider using the `--user` option or check the permissions.

# %%
pip install opencv-contrib-python==3.4.2.16
# Out:
# Collecting opencv-contrib-python==3.4.2.16
#   Using cached https://files.pythonhosted.org/packages/a2/1c/778cb8a5f4026d49e299d34a98791599f7485553c29889385c43158b6f43/opencv_contrib_python-3.4.2.16-cp37-cp37m-win_amd64.whl
# Requirement already satisfied: numpy>=1.14.5 in c:\users\user\anaconda3\lib\site-packages (from opencv-contrib-python==3.4.2.16) (1.16.5)
# Installing collected packages: opencv-contrib-python
# Successfully installed opencv-contrib-python-3.4.2.16
# Note: you may need to restart the kernel to use updated packages.

# %%
--user
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-adef3c864ec1> in <module>
# ----> 1 --user
#
# NameError: name 'user' is not defined

# %%
pip install --user package_name
# Out:
# Collecting package_name
#   Downloading https://files.pythonhosted.org/packages/61/5f/6690d5f0bad41818063e3f436c101deff0f243adede1d23642deb607349d/package_name-0.1.tar.gz
# Building wheels for collected packages: package-name
#   Building wheel for package-name (setup.py): started
#   Building wheel for package-name (setup.py): finished with status 'done'
#   Created wheel for package-name: filename=package_name-0.1-cp37-none-any.whl size=1274 sha256=66b1f406c6b2c329dd76cb4b83cf794f49bd366e86a154e8dde21761d044d6e6
#   Stored in directory: C:\Users\User\AppData\Local\pip\Cache\wheels\3d\ed\6d\a2d22a1d3f8ae59dd045ec72e2d7aa51fd3f8a1faac24926ba
# Successfully built package-name
# Installing collected packages: package-name
# Successfully installed package-name-0.1
# Note: you may need to restart the kernel to use updated packages.
