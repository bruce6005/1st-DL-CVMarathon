# %% [markdown]
# ## 『本次練習內容』
# #### 搭建一個能識別驗證碼的模型(CNN+CTC)

# %% [markdown]
# ## 『本次練習目的』
#   #### 了解如何結合CNN與CTC Loss
#   #### 有時間學員也可以延伸閱讀CNN+RNN+CTC模型
#   #### 沒有GPU的學員可以使用Colab，可以參考問答區的文章

# %%
## 使用Colab可先run這裡的code
#假如要連結自己的雲端硬碟再開啟
#from google.colab import drive
#drive.mount('/content/gdrive')
#檢查GPU
nvidia-smi
##安裝產生驗證碼的套件
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-7c0e4f66e517> in <module>
#       4 #drive.mount('/content/gdrive')
#       5 #檢查GPU
# ----> 6 nvidia-smi
#       7 ##安裝產生驗證碼的套件
#
# NameError: name 'nvidia' is not defined

# %% [markdown]
# ## 記得先 pip install captcha

# %%
pip install captcha
# Out:
# Requirement already satisfied: captcha in c:\users\user\anaconda3\lib\site-packages (0.3)
# Requirement already satisfied: Pillow in c:\users\user\anaconda3\lib\site-packages (from captcha) (6.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## 產生驗證碼

# %%
pip install keras
# Out:
# Requirement already satisfied: keras in c:\users\user\anaconda3\lib\site-packages (2.2.4)
# Requirement already satisfied: numpy>=1.9.1 in c:\users\user\anaconda3\lib\site-packages (from keras) (1.16.5)
# Requirement already satisfied: scipy>=0.14 in c:\users\user\anaconda3\lib\site-packages (from keras) (1.3.1)
# Requirement already satisfied: six>=1.9.0 in c:\users\user\anaconda3\lib\site-packages (from keras) (1.12.0)
# Requirement already satisfied: pyyaml in c:\users\user\anaconda3\lib\site-packages (from keras) (5.1.2)
# Requirement already satisfied: h5py in c:\users\user\anaconda3\lib\site-packages (from keras) (2.9.0)
# Requirement already satisfied: keras_applications>=1.0.6 in c:\users\user\anaconda3\lib\site-packages (from keras) (1.0.8)
# Requirement already satisfied: keras_preprocessing>=1.0.5 in c:\users\user\anaconda3\lib\site-packages (from keras) (1.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from keras.backend import ctc_batch_cost
def ctc_lambda_func(args):
    y_pred, labels, input_length, label_length = args
    # the 2 is critical here since the first couple outputs of the RNN
    # tend to be garbage:
    y_pred = y_pred[:, 2:, :]
    return K.ctc_batch_cost(labels, y_pred, input_length, label_length)

# %%
from captcha.image import ImageCaptcha
import matplotlib.pyplot as plt
import numpy as np
import random

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import string
##驗證碼包含0-10數字以及26個英文字母
characters = string.digits + string.ascii_uppercase
print(characters)

##設定產生圖片尺寸，以及總類別，n_class之所以要加一是為了留一個位置給Blank
width, height, n_len, n_class = 170, 80, 4, len(characters)+1

##設定產生驗證碼的generator
generator = ImageCaptcha(width=width, height=height)

##我們先練習固定長度4個字的驗證碼
random_str = ''.join([random.choice(characters) for j in range(4)])
img = generator.generate_image(random_str)

plt.imshow(img)
plt.title(random_str)
# Out:
# 0123456789ABCDEFGHIJKLMNOPQRSTUVWXYZ
# Text(0.5, 1.0, 'C4P0')

# %% [markdown]
# ## 自己搭建一個CNN模型使得output feature Map 高度被壓縮成小於4，8<寬度<20
# #### 解答的output feature Map 為 (batch_size,1,13,32)

# %%
from keras.models import *
from keras.layers import *
import keras

rnn_size = 128

input_tensor = Input((height,width, 3))
x = input_tensor
#自己設計CNN層

for i in range(4):
    x = Convolution2D(32, 3, 3, activation='sigmoid')(x)
    x = keras.layers.BatchNormalization(axis=-1)(x)
    x = Convolution2D(32, 3, 3, activation='sigmoid')(x)
    x = keras.layers.BatchNormalization(axis=-1)(x)
    if i <3:
        x = MaxPooling2D(pool_size=(2, 2))(x)
    else:
        x = MaxPooling2D(pool_size=(2, 1))(x)

##記錄輸出CNN尺寸，loss部分需要這個資訊
##conv_shape=(Batch_size,輸出高度,輸出寬度,輸出深度)
conv_shape = x.get_shape()

##從(Batch_size,輸出高度,輸出寬度,輸出深度)變成(Batch_size,輸出寬度,輸出深度*輸出高度)，以符合ctc loss需求
x = Reshape(target_shape=(int(conv_shape[2]), int(conv_shape[1]*conv_shape[3])))(x)

x = Dense(32, activation='relu')(x)

x = Dropout(0.25)(x)
x = Dense(n_class, activation='softmax')(x)


##包裝用來預測的model
base_model = Model(input=input_tensor, output=x)


##設定要給CTC Loss的資訊
labels = Input(name='the_labels', shape=[n_len], dtype='float32')
input_length = Input(name='input_length', shape=[1], dtype='int64')
label_length = Input(name='label_length', shape=[1], dtype='int64')
loss_out = Lambda(ctc_lambda_func, output_shape=(1,), 
                  name='ctc')([x, labels, input_length, label_length])

##這裡的model是用來計算loss
model = Model(input=[input_tensor, labels, input_length, label_length], output=[loss_out])

##之所以要lambda y_true, y_pred: y_pred是因為我們的loss已經包在網路裡，會output:y_true, y_pred，而我們只需要y_pred
model.compile(loss={'ctc': lambda y_true, y_pred: y_pred}, optimizer='SGD')
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), activation="sigmoid")`
#   if sys.path[0] == '':
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), activation="sigmoid")`
#
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:35: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=[<tf.Tenso..., outputs=[<tf.Tenso...)`

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            (None, 80, 170, 3)   0
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 78, 168, 32)  896         input_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 78, 168, 32)  128         conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 76, 166, 32)  9248        batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 76, 166, 32)  128         conv2d_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 38, 83, 32)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 36, 81, 32)   9248        max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 36, 81, 32)   128         conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 34, 79, 32)   9248        batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 34, 79, 32)   128         conv2d_8[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 17, 39, 32)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 15, 37, 32)   9248        max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 15, 37, 32)   128         conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 13, 35, 32)   9248        batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 13, 35, 32)   128         conv2d_10[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 6, 17, 32)    0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 4, 15, 32)    9248        max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 4, 15, 32)    128         conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 2, 13, 32)    9248        batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 2, 13, 32)    128         conv2d_12[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 1, 13, 32)    0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# reshape_3 (Reshape)             (None, 13, 32)       0           max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 13, 32)       1056        reshape_3[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 13, 32)       0           dense_5[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 13, 37)       1221        dropout_3[0][0]
# __________________________________________________________________________________________________
# the_labels (InputLayer)         (None, 4)            0
# __________________________________________________________________________________________________
# input_length (InputLayer)       (None, 1)            0
# __________________________________________________________________________________________________
# label_length (InputLayer)       (None, 1)            0
# __________________________________________________________________________________________________
# ctc (Lambda)                    (None, 1)            0           dense_6[0][0]
#                                                                  the_labels[0][0]
#                                                                  input_length[0][0]
#                                                                  label_length[0][0]
# ==================================================================================================
# Total params: 68,933
# Trainable params: 68,421
# Non-trainable params: 512
# __________________________________________________________________________________________________

# %%
from keras import backend as K
import keras

##CTC Loss需要四個資訊，分別是
## Label
## 預測
## CNN OUTPUT寬度
## 預測影像所包含文字長度
def ctc_lambda_func(args):
    y_pred, labels, input_length, label_length = args
    return K.ctc_batch_cost(labels, y_pred, input_length, label_length)

# %%
##設計generator產生training data
## 產生包含要給loss的資訊
## X=輸入影像
## np.ones(batch_size)*int(conv_shape[2])=CNN輸出feature Map寬度
## np.ones(batch_size)*n_len=字串長度(可浮動)

def gen(batch_size=128):
    X = np.zeros((batch_size,height, width, 3), dtype=np.uint8)
    y = np.zeros((batch_size, n_len), dtype=np.uint8)
    while True:
        generator = ImageCaptcha(width=width, height=height)
        for i in range(batch_size):
            random_str = ''.join([random.choice(characters) for j in range(4)])
            X[i] = np.array(generator.generate_image(random_str))
            y[i] = [characters.find(x) for x in random_str]
        yield [X, y,np.ones(batch_size)*int(conv_shape[2]), np.ones(batch_size)*n_len], np.ones(batch_size)

# %%
next_ge=gen(batch_size=1)
test_ge=next(next_ge)
plt.imshow(test_ge[0][0][0])
print('Label: ',test_ge[0][1])
print('CNN輸出寬度: ',test_ge[0][2])
print('字串長度(可浮動): ',test_ge[0][3])
# Out:
# Label:  [[ 4 13 10 34]]
# CNN輸出寬度:  [13.]
# 字串長度(可浮動):  [4.]

# %% [markdown]
# ## 開始訓練

# %%
model.fit_generator(gen(32), steps_per_epoch=300, epochs=60)
# Out:
# Epoch 1/60
# 109/300 [=========>....................] - ETA: 3:35 - loss: 16.9610

# %% [markdown]
# ## 預測

# %%
characters2 = characters + ' '
[X_test, y_test, _, _], _  = next(gen(1))
y_pred = base_model.predict(X_test)
##用ctc_decode得到解答，自己寫可以參考下方
out = K.get_value(K.ctc_decode(y_pred, input_length=np.ones(y_pred.shape[0])*y_pred.shape[1], )[0][0])
out = ''.join([characters[x] for x in out[0]])
y_true = ''.join([characters[x] for x in y_test[0]])

plt.imshow(X_test[0])
plt.title('pred:' + str(out) + '\ntrue: ' + str(y_true))

argmax = np.argmax(y_pred, axis=2)[0]

# %% [markdown]
# ## 自己寫 decode CTC

# %%
## 其中0代表預測為空格，如果預測相同字符之間沒有空格要移除
word=''
n=''
for single_result in y_pred[0].argmax(1):
    if single_result != 36:
        if n != single_result:
            word+=characters[single_result]
    n=single_result

# %% [markdown]
# ## 額外參考：加入RNN的神經網路

# %%
from keras.models import *
from keras.layers import *
rnn_size = 128

input_tensor = Input((height,width, 3))
x = input_tensor
for i in range(4):
    x = Convolution2D(32, 3, 3, activation='relu')(x)
    x = keras.layers.BatchNormalization(axis=-1)(x)
    x = Convolution2D(32, 3, 3, activation='relu')(x)
    x = keras.layers.BatchNormalization(axis=-1)(x)
    if i <3:
        x = MaxPooling2D(pool_size=(2, 2))(x)
    else:
        x = MaxPooling2D(pool_size=(2, 1))(x)


conv_shape = x.get_shape()
x = Reshape(target_shape=(int(conv_shape[2]), int(conv_shape[1]*conv_shape[3])))(x)

x = Dense(32, activation='relu')(x)

gru_1 = GRU(rnn_size, return_sequences=True, init='he_normal', name='gru1')(x)
gru_1b = GRU(rnn_size, return_sequences=True, go_backwards=True, 
             init='he_normal', name='gru1_b')(x)
gru1_merged = keras.layers.add([gru_1, gru_1b])

gru_2 = GRU(rnn_size, return_sequences=True, init='he_normal', name='gru2')(gru1_merged)
gru_2b = GRU(rnn_size, return_sequences=True, go_backwards=True, 
             init='he_normal', name='gru2_b')(gru1_merged)
x = keras.layers.Concatenate()([gru_2, gru_2b])

x = Dropout(0.25)(x)
x = Dense(n_class, init='he_normal', activation='softmax')(x)

base_model = Model(input=input_tensor, output=x)

labels = Input(name='the_labels', shape=[n_len], dtype='float32')
input_length = Input(name='input_length', shape=[1], dtype='int64')
label_length = Input(name='label_length', shape=[1], dtype='int64')
loss_out = Lambda(ctc_lambda_func, output_shape=(1,), 
                  name='ctc')([x, labels, input_length, label_length])

model = Model(input=[input_tensor, labels, input_length, label_length], output=[loss_out])
model.compile(loss={'ctc': lambda y_true, y_pred: y_pred}, optimizer='Adam')
# Out:
# /Users/chening/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:8: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), activation="relu")`
#
# /Users/chening/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:10: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), activation="relu")`
#   # Remove the CWD from sys.path while we load stuff.
# /Users/chening/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:23: UserWarning: Update your `GRU` call to the Keras 2 API: `GRU(128, return_sequences=True, name="gru1", kernel_initializer="he_normal")`
# /Users/chening/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:25: UserWarning: Update your `GRU` call to the Keras 2 API: `GRU(128, return_sequences=True, go_backwards=True, name="gru1_b", kernel_initializer="he_normal")`
# /Users/chening/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:28: UserWarning: Update your `GRU` call to the Keras 2 API: `GRU(128, return_sequences=True, name="gru2", kernel_initializer="he_normal")`
# /Users/chening/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:30: UserWarning: Update your `GRU` call to the Keras 2 API: `GRU(128, return_sequences=True, go_backwards=True, name="gru2_b", kernel_initializer="he_normal")`
# /Users/chening/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:34: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(37, activation="softmax", kernel_initializer="he_normal")`
# /Users/chening/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:36: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
# /Users/chening/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:44: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=[<tf.Tenso..., outputs=[<tf.Tenso...)`

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            (None, 80, 170, 3)   0
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 78, 168, 32)  896         input_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 78, 168, 32)  128         conv2d_25[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 76, 166, 32)  9248        batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 76, 166, 32)  128         conv2d_26[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_13 (MaxPooling2D) (None, 38, 83, 32)   0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 36, 81, 32)   9248        max_pooling2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 36, 81, 32)   128         conv2d_27[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 34, 79, 32)   9248        batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 34, 79, 32)   128         conv2d_28[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_14 (MaxPooling2D) (None, 17, 39, 32)   0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 15, 37, 32)   9248        max_pooling2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 15, 37, 32)   128         conv2d_29[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 13, 35, 32)   9248        batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 13, 35, 32)   128         conv2d_30[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_15 (MaxPooling2D) (None, 6, 17, 32)    0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 4, 15, 32)    9248        max_pooling2d_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 4, 15, 32)    128         conv2d_31[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 2, 13, 32)    9248        batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 2, 13, 32)    128         conv2d_32[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_16 (MaxPooling2D) (None, 1, 13, 32)    0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# reshape_4 (Reshape)             (None, 13, 32)       0           max_pooling2d_16[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 13, 32)       1056        reshape_4[0][0]
# __________________________________________________________________________________________________
# gru1 (GRU)                      (None, 13, 128)      61824       dense_7[0][0]
# __________________________________________________________________________________________________
# gru1_b (GRU)                    (None, 13, 128)      61824       dense_7[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 13, 128)      0           gru1[0][0]
#                                                                  gru1_b[0][0]
# __________________________________________________________________________________________________
# gru2 (GRU)                      (None, 13, 128)      98688       add_2[0][0]
# __________________________________________________________________________________________________
# gru2_b (GRU)                    (None, 13, 128)      98688       add_2[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 13, 256)      0           gru2[0][0]
#                                                                  gru2_b[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 13, 256)      0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 13, 37)       9509        dropout_4[0][0]
# __________________________________________________________________________________________________
# the_labels (InputLayer)         (None, 4)            0
# __________________________________________________________________________________________________
# input_length (InputLayer)       (None, 1)            0
# __________________________________________________________________________________________________
# label_length (InputLayer)       (None, 1)            0
# __________________________________________________________________________________________________
# ctc (Lambda)                    (None, 1)            0           dense_8[0][0]
#                                                                  the_labels[0][0]
#                                                                  input_length[0][0]
#                                                                  label_length[0][0]
# ==================================================================================================
# Total params: 398,245
# Trainable params: 397,733
# Non-trainable params: 512
# __________________________________________________________________________________________________
